# %%
#Import Library

import pandas as pd
import numpy as np
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import MinMaxScaler,LabelEncoder

# %%
#Read Data
dfloan = pd.read_csv('loanTrain.csv')
dfloan.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# 2             1.0         Urban           Y
# 3             1.0         Urban           Y
# 4             1.0         Urban           Y

# %%
#Identify columns
dfloan.columns
# Out:
# Index(['Loan_ID', 'Gender', 'Married', 'Dependents', 'Education',
#        'Self_Employed', 'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term', 'Credit_History', 'Property_Area', 'Loan_Status'],
#       dtype='object')

# %%
#Identify Target column
dfloan['Loan_Status'].unique()
# Out:
# array(['Y', 'N'], dtype=object)

# %%
dfloan['Loan_Status'].value_counts()
# Out:
# Loan_Status
# Y    422
# N    192
# Name: count, dtype: int64

# %%
#Shape of data
dfloan.shape
# Out:
# (614, 13)

# %%
#number of Unique items in each column
dfloan.nunique()
# Out:
# Loan_ID              614
# Gender                 2
# Married                2
# Dependents             4
# Education              2
# Self_Employed          2
# ApplicantIncome      505
# CoapplicantIncome    287
# LoanAmount           203
# Loan_Amount_Term      10
# Credit_History         2
# Property_Area          3
# Loan_Status            2
# dtype: int64

# %%
#Create a copy of original data
df = dfloan.copy()
df.head(3)
# Out:
#     Loan_ID Gender Married Dependents Education Self_Employed  \
# 0  LP001002   Male      No          0  Graduate            No
# 1  LP001003   Male     Yes          1  Graduate            No
# 2  LP001005   Male     Yes          0  Graduate           Yes
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# 2             1.0         Urban           Y

# %%
#Drop duplicate data columns
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Loan_ID, Gender, Married, Dependents, Education, Self_Employed, ApplicantIncome, CoapplicantIncome, LoanAmount, Loan_Amount_Term, Credit_History, Property_Area, Loan_Status]
# Index: []

# %%
#Identify missing values in each data column
df.isna().sum()
# Out:
# Loan_ID               0
# Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
#Identify numerical data columns & Non-Numerical data columns

num_cols = list(df.select_dtypes('number').columns)
non_num_cols = list(df.select_dtypes(exclude = 'number').columns)

print(num_cols)
print()
print(non_num_cols)
# Out:
# ['ApplicantIncome', 'CoapplicantIncome', 'LoanAmount', 'Loan_Amount_Term', 'Credit_History']
#
# ['Loan_ID', 'Gender', 'Married', 'Dependents', 'Education', 'Self_Employed', 'Property_Area', 'Loan_Status']

# %%
#Impute using mostfrequent value Simple imputer
cat_imputer = SimpleImputer(strategy = 'most_frequent')
df[non_num_cols] = cat_imputer.fit_transform(df[non_num_cols])

# %%
#Impute using mean value value Simple imputer
num_imputer = SimpleImputer(strategy = 'mean')
df[num_cols] = num_imputer.fit_transform(df[num_cols])

# %%
df.isna().sum()
# Out:
# Loan_ID              0
# Gender               0
# Married              0
# Dependents           0
# Education            0
# Self_Employed        0
# ApplicantIncome      0
# CoapplicantIncome    0
# LoanAmount           0
# Loan_Amount_Term     0
# Credit_History       0
# Property_Area        0
# Loan_Status          0
# dtype: int64

# %%
#Sum up Applicant income and co-applicant income
df['ApplicantIncome'] = df['ApplicantIncome'] + df['CoapplicantIncome']

# %%
df.head(3)
# Out:
#     Loan_ID Gender Married Dependents Education Self_Employed  \
# 0  LP001002   Male      No          0  Graduate            No
# 1  LP001003   Male     Yes          1  Graduate            No
# 2  LP001005   Male     Yes          0  Graduate           Yes
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0           5849.0                0.0  146.412162             360.0
# 1           6091.0             1508.0  128.000000             360.0
# 2           3000.0                0.0   66.000000             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# 2             1.0         Urban           Y

# %%
#Remove unnecessary data columns

df1 = df.drop(['Loan_ID','CoapplicantIncome'] , axis = 'columns')
df1.head(3)
# Out:
#   Gender Married Dependents Education Self_Employed  ApplicantIncome  \
# 0   Male      No          0  Graduate            No           5849.0
# 1   Male     Yes          1  Graduate            No           6091.0
# 2   Male     Yes          0  Graduate           Yes           3000.0
#
#    LoanAmount  Loan_Amount_Term  Credit_History Property_Area Loan_Status
# 0  146.412162             360.0             1.0         Urban           Y
# 1  128.000000             360.0             1.0         Rural           N
# 2   66.000000             360.0             1.0         Urban           Y

# %%
#Perform Encoding
df1['Dependents'].unique()
df1['Education'].unique()
df1['Property_Area'].unique()
# Out:
# array(['Urban', 'Rural', 'Semiurban'], dtype=object)

# %%
print(non_num_cols)
non_num_cols.remove('Loan_ID')
# Out:
# ['Loan_ID', 'Gender', 'Married', 'Dependents', 'Education', 'Self_Employed', 'Property_Area', 'Loan_Status']

# %%
print(non_num_cols)
# Out:
# ['Gender', 'Married', 'Dependents', 'Education', 'Self_Employed', 'Property_Area', 'Loan_Status']

# %%
for col in non_num_cols:
    le = LabelEncoder()
    df1[col] = le.fit_transform(df1[col])

# %%
df1.head(3)
# Out:
#    Gender  Married  Dependents  Education  Self_Employed  ApplicantIncome  \
# 0       1        0           0          0              0           5849.0
# 1       1        1           1          0              0           6091.0
# 2       1        1           0          0              1           3000.0
#
#    LoanAmount  Loan_Amount_Term  Credit_History  Property_Area  Loan_Status
# 0  146.412162             360.0             1.0              2            1
# 1  128.000000             360.0             1.0              0            0
# 2   66.000000             360.0             1.0              2            1

# %%
#Log transformation of numerical columns
num_cols
num_cols.remove('CoapplicantIncome')
num_cols.remove('Credit_History')
print(num_cols)
# Out:
# ['ApplicantIncome', 'LoanAmount', 'Loan_Amount_Term']

# %%
df1[num_cols] = np.log(df1[num_cols])

# %%
df1.head(3)
# Out:
#    Gender  Married  Dependents  Education  Self_Employed  ApplicantIncome  \
# 0       1        0           0          0              0         8.674026
# 1       1        1           1          0              0         8.714568
# 2       1        1           0          0              1         8.006368
#
#    LoanAmount  Loan_Amount_Term  Credit_History  Property_Area  Loan_Status
# 0    4.986426          5.886104             1.0              2            1
# 1    4.852030          5.886104             1.0              0            0
# 2    4.189655          5.886104             1.0              2            1

# %%
#Seperate features and labels for creating ML Model

X = df1.drop('Loan_Status' , axis = 'columns')
y = df1['Loan_Status']

# %%
y.value_counts()
# Out:
# Loan_Status
# 1    422
# 0    192
# Name: count, dtype: int64

# %%
#Split into train & test
from sklearn.model_selection import train_test_split
xtrain,xtest,ytrain,ytest = train_test_split(X,y,train_size=0.78,random_state=0)

# %%
xtrain
# Out:
#      Gender  Married  Dependents  Education  Self_Employed  ApplicantIncome  \
# 315       1        1           1          1              0         8.524963
# 318       0        0           1          0              0         8.172164
# 132       1        0           0          0              0         7.907652
# 566       1        0           0          0              0         8.111628
# 279       0        1           0          1              0         8.318742
# ..      ...      ...         ...        ...            ...              ...
# 277       1        1           0          0              0         8.390041
# 9         1        1           1          0              0        10.077819
# 359       1        1           3          0              0         9.028099
# 192       1        1           0          1              0         8.705000
# 559       0        1           0          0              0         8.777401
#
#      LoanAmount  Loan_Amount_Term  Credit_History  Property_Area
# 315    4.709530          5.192957        1.000000              2
# 318    4.718499          5.886104        0.842199              1
# 132    4.248495          5.886104        1.000000              1
# 566    4.248495          5.886104        1.000000              2
# 279    4.820282          5.886104        0.842199              0
# ..          ...               ...             ...            ...
# 277    4.382027          5.886104        1.000000              2
# 9      5.855072          5.886104        1.000000              1
# 359    5.298317          5.886104        1.000000              1
# 192    5.075174          5.886104        1.000000              2
# 559    5.204007          5.886104        1.000000              1
#
# [478 rows x 10 columns]

# %%
#Perform data scaling
from sklearn.preprocessing import MinMaxScaler
scaler =  MinMaxScaler()

scaler.fit(xtrain)

xtrainScaled = scaler.transform(xtrain)
xtestScaled = scaler.transform(xtest)

# %%
#Train your model

from sklearn.linear_model import LogisticRegression

model1 = LogisticRegression()

model1.fit(xtrainScaled,ytrain)
# Out:
# LogisticRegression()

# %%
#Evaluate model performance

print("Accuracy on training data" , model1.score(xtrainScaled,ytrain))
print("Accuracy on test data" , model1.score(xtestScaled,ytest))
# Out:
# Accuracy on training data 0.8075313807531381
# Accuracy on test data 0.8161764705882353

# %%
#Serialization or Save your Model

import joblib
joblib.dump(model1,"loan_model.pkl")
# Out:
# ['loan_model.pkl']

# %%
print(model1.coef_)
# Out:
# [[-0.10333467  0.33792768  0.27051517 -0.40697909  0.03335306  0.20880313
#   -0.95670688  0.15723909  3.30157767  0.25685782]]

# %%
#Deserialization or Load model
import joblib
loaded_model = joblib.load("loan_model.pkl")

# %%
print(loaded_model.coef_)
# Out:
# [[-0.10333467  0.33792768  0.27051517 -0.40697909  0.03335306  0.20880313
#   -0.95670688  0.15723909  3.30157767  0.25685782]]
